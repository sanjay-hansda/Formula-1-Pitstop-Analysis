# %% [markdown]
# # Background
#
# What I love about Formula 1 and its place in sports, is the attention all the teams pay to every ounce of performance it can gain on and off the track. It's pursuit of continuous improvement is truly admirable. On that note, I was very interested in the data on their pit stops and how it might provide some insights to parts of the sport I had not considered before.
#
# Since the beginning of Formula 1, the pit stop has been an iconic part of the race format. At the beginning of the sport, the time spent in the pit lane made up a significant portion of the race. Being the optimizers these teams were, the time spent in the pit played a key part of shaving meaningful time off a team's race ultimately translating into success on the track. Technologies were developed and processes evaluated to minimize pit times, and rules changed over time to adapt to both performance and safety developments.
#
# Technologies have gotten to a point where cars no longer need to be pitted to refuel or change tyres; however, the pit stop is a mainstay in the sport and adds an element of uncertainty and strategies making the sport all the more exciting for us the spectators. This notebook will explore the pit stop data and shed some light on how important the pit stop is in a race and what does it mean to have a "good" pit stop.

# %% [markdown]
# # Objective
#
# This notebook will explore F1 pit stop data and gain a better understanding of how the pit stop plays its role in the F1 Grand Prix. Using the findings, I will attempt to answer the questions below which will hopefully yield some new perspectives on the sport!
#
# ## Questions I want to answer:
# * How did pit stop durations change over time?
# * Is there a relationship between pit stop durations and constructor?
# * Is there a relationship between pit stop durations and race circuit?
# * What is the time spent in the pit lane as a percentage of the race?
# * Who is the best constructor on pit stop performance?
#
# Without any further ado, let's go!

# %% [markdown]
# <div style="width:100%; text-align:center"><img style="align:middle; width:100%" src="https://c.tenor.com/tg28WEO2hLoAAAAC/f1-pitstop.gif"></div>

# %% [markdown]
# # Setup
#
# The usual boring stuff but necessary stuff to get all set up. Importing libraries, reading in data, and cleaning it up. You know the drill.

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
import plotly.express as px

import os
fnames = []
fpaths = []
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        fnames.append(filename.split('.')[0])
        fpaths.append(os.path.join(dirname, filename))
        print(os.path.join(dirname, filename))

# %% [markdown]
# ## Reading the data

# %%
# Constructor color mapping
constructor_color_map = {
    'Toro Rosso':'#0000FF',
    'Mercedes':'#6CD3BF',
    'Red Bull':'#1E5BC6',
    'Ferrari':'#ED1C24',
    'Williams':'#37BEDD',
    'Force India':'#FF80C7',
    'Virgin':'#c82e37',
    'Renault':'#FFD800',
    'McLaren':'#F58020',
    'Sauber':'#006EFF',
    'Lotus':'#FFB800',
    'HRT':'#b2945e',
    'Caterham':'#0b361f',
    'Lotus F1':'#FFB800',
    'Marussia':'#6E0000',
    'Manor Marussia':'#6E0000',
    'Haas F1 Team':'#B6BABD',
    'Racing Point':'#F596C8',
    'Aston Martin':'#2D826D',
    'Alfa Romeo':'#B12039',
    'AlphaTauri':'#4E7C9B',
    'Alpine F1 Team':'#2293D1'
}

# %% [markdown]
# # Pit Stop Data
#
# <b>Note:</b> In the context of the data I'm using, pit stop durations include the total time in the pit lane and not only when the car is stationary.

# %%
pitStops
# Out:
#        raceId  driverId  stop  lap   pitTime duration  milliseconds  seconds
# 0         841       153     1    1  17:05:23   26.898         26898   26.898
# 1         841        30     1    1  17:05:52   25.021         25021   25.021
# 2         841        17     1   11  17:20:48   23.426         23426   23.426
# 3         841         4     1   12  17:22:34   23.251         23251   23.251
# 4         841        13     1   13  17:24:10   23.842         23842   23.842
# ...       ...       ...   ...  ...       ...      ...           ...      ...
# 10985    1132       807     2   39  16:06:28   30.265         30265   30.265
# 10986    1132       840     2   39  16:06:33   29.469         29469   29.469
# 10987    1132       839     4   38  16:06:52   29.086         29086   29.086
# 10988    1132       815     4   47  16:20:38   28.871         28871   28.871
# 10989    1132       832     3   50  16:22:59   28.706         28706   28.706
#
# [10990 rows x 8 columns]

# %%
pitStops.describe().T
# Out:
#                 count          mean            std        min          25%  \
# raceId        10990.0    975.731665      89.041843    841.000    893.00000
# driverId      10990.0    542.601274     385.555797      1.000     20.00000
# stop          10990.0      1.797179       1.540691      1.000      1.00000
# lap           10990.0     25.314741      14.896984      1.000     13.00000
# milliseconds  10990.0  85304.309554  311489.432628  12897.000  21951.25000
# seconds       10990.0     85.304310     311.489433     12.897     21.95125
#
#                     50%         75%          max
# raceId          967.000   1055.0000     1132.000
# driverId        817.000    832.0000      860.000
# stop              2.000      2.0000       70.000
# lap              25.000     36.0000       78.000
# milliseconds  23629.000  26503.5000  3069017.000
# seconds          23.629     26.5035     3069.017

# %%
newResults = pd.merge(results,races,left_on='raceId',right_index=True,how='left')
newResults = pd.merge(newResults,circuits,left_on='circuitId',right_index=True,how='left')
newResults = pd.merge(newResults,constructors,left_on='constructorId',right_index=True,how='left')
newResults = pd.merge(newResults,drivers,left_on='driverId',right_index=True,how='left')
newResults
# Out:
#           raceId  driverId  constructorId  number_x  grid  position  \
# resultId
# 1             18         1              1      22.0     1       1.0
# 2             18         2              2       3.0     5       2.0
# 3             18         3              3       7.0     7       3.0
# 4             18         4              4       5.0    11       4.0
# 5             18         5              1      23.0     3       5.0
# ...          ...       ...            ...       ...   ...       ...
# 26520       1132       839            214      31.0    18      16.0
# 26521       1132       815              9      11.0     0      17.0
# 26522       1132       855             15      24.0    14      18.0
# 26523       1132       847            131      63.0     1       NaN
# 26524       1132       842            214      10.0    19       NaN
#
#          positionText  positionOrder  points  laps  ...  \
# resultId                                            ...
# 1                   1              1    10.0    58  ...
# 2                   2              2     8.0    58  ...
# 3                   3              3     6.0    58  ...
# 4                   4              4     5.0    58  ...
# 5                   5              5     4.0    58  ...
# ...               ...            ...     ...   ...  ...
# 26520              16             16     0.0    50  ...
# 26521              17             17     0.0    50  ...
# 26522              18             18     0.0    50  ...
# 26523               R             19     0.0    33  ...
# 26524               W             20     0.0     0  ...
#
#                                              constructorUrl   driverRef  \
# resultId
# 1                      http://en.wikipedia.org/wiki/McLaren    hamilton
# 2                   http://en.wikipedia.org/wiki/BMW_Sauber    heidfeld
# 3         http://en.wikipedia.org/wiki/Williams_Grand_Pr...     rosberg
# 4         http://en.wikipedia.org/wiki/Renault_in_Formul...      alonso
# 5                      http://en.wikipedia.org/wiki/McLaren  kovalainen
# ...                                                     ...         ...
# 26520           http://en.wikipedia.org/wiki/Alpine_F1_Team        ocon
# 26521          http://en.wikipedia.org/wiki/Red_Bull_Racing       perez
# 26522        http://en.wikipedia.org/wiki/Sauber_Motorsport        zhou
# 26523     http://en.wikipedia.org/wiki/Mercedes-Benz_in_...     russell
# 26524           http://en.wikipedia.org/wiki/Alpine_F1_Team       gasly
#
#           number_y  code  forename     surname         dob  driverNationality  \
# resultId
# 1             44.0   HAM     Lewis    Hamilton  1985-01-07            British
# 2              NaN   HEI      Nick    Heidfeld  1977-05-10             German
# 3              6.0   ROS      Nico     Rosberg  1985-06-27             German
# 4             14.0   ALO  Fernando      Alonso  1981-07-29            Spanish
# 5              NaN   KOV    Heikki  Kovalainen  1981-10-19            Finnish
# ...            ...   ...       ...         ...         ...                ...
# 26520         31.0   OCO   Esteban        Ocon  1996-09-17             French
# 26521         11.0   PER    Sergio       Pérez  1990-01-26            Mexican
# 26522         24.0   ZHO    Guanyu        Zhou  1999-05-30            Chinese
# 26523         63.0   RUS    George     Russell  1998-02-15            British
# 26524         10.0   GAS    Pierre       Gasly  1996-02-07             French
#
#                                                   driverUrl         driverName
# resultId
# 1               http://en.wikipedia.org/wiki/Lewis_Hamilton     Lewis Hamilton
# 2                http://en.wikipedia.org/wiki/Nick_Heidfeld      Nick Heidfeld
# 3                 http://en.wikipedia.org/wiki/Nico_Rosberg       Nico Rosberg
# 4              http://en.wikipedia.org/wiki/Fernando_Alonso    Fernando Alonso
# 5            http://en.wikipedia.org/wiki/Heikki_Kovalainen  Heikki Kovalainen
# ...                                                     ...                ...
# 26520             http://en.wikipedia.org/wiki/Esteban_Ocon       Esteban Ocon
# 26521        http://en.wikipedia.org/wiki/Sergio_P%C3%A9rez       Sergio Pérez
# 26522              http://en.wikipedia.org/wiki/Zhou_Guanyu        Guanyu Zhou
# 26523     http://en.wikipedia.org/wiki/George_Russell_(r...     George Russell
# 26524             http://en.wikipedia.org/wiki/Pierre_Gasly       Pierre Gasly
#
# [26519 rows x 56 columns]

# %%
newPitStops = pd.merge(pitStops,races,left_on='raceId',right_index=True,how='left')
newPitStops = pd.merge(newPitStops,circuits,left_on='circuitId',right_index=True,how='left')
newPitStops = pd.merge(newPitStops,newResults[['raceId','driverId','driverName','constructorId','constructorName']],left_on=['raceId','driverId'],right_on=['raceId','driverId'])
newPitStops
# Out:
#        raceId  driverId  stop  lap   pitTime duration  milliseconds  seconds  \
# 0         841       153     1    1  17:05:23   26.898         26898   26.898
# 1         841        30     1    1  17:05:52   25.021         25021   25.021
# 2         841        17     1   11  17:20:48   23.426         23426   23.426
# 3         841         4     1   12  17:22:34   23.251         23251   23.251
# 4         841        13     1   13  17:24:10   23.842         23842   23.842
# ...       ...       ...   ...  ...       ...      ...           ...      ...
# 10985    1132       807     2   39  16:06:28   30.265         30265   30.265
# 10986    1132       840     2   39  16:06:33   29.469         29469   29.469
# 10987    1132       839     4   38  16:06:52   29.086         29086   29.086
# 10988    1132       815     4   47  16:20:38   28.871         28871   28.871
# 10989    1132       832     3   50  16:22:59   28.706         28706   28.706
#
#        year  round  ...                     circuitName circuitLocation  \
# 0      2011      1  ...  Albert Park Grand Prix Circuit       Melbourne
# 1      2011      1  ...  Albert Park Grand Prix Circuit       Melbourne
# 2      2011      1  ...  Albert Park Grand Prix Circuit       Melbourne
# 3      2011      1  ...  Albert Park Grand Prix Circuit       Melbourne
# 4      2011      1  ...  Albert Park Grand Prix Circuit       Melbourne
# ...     ...    ...  ...                             ...             ...
# 10985  2024     12  ...             Silverstone Circuit     Silverstone
# 10986  2024     12  ...             Silverstone Circuit     Silverstone
# 10987  2024     12  ...             Silverstone Circuit     Silverstone
# 10988  2024     12  ...             Silverstone Circuit     Silverstone
# 10989  2024     12  ...             Silverstone Circuit     Silverstone
#
#       circuitCountry      lat        lng  alt  \
# 0          Australia -37.8497  144.96800   10
# 1          Australia -37.8497  144.96800   10
# 2          Australia -37.8497  144.96800   10
# 3          Australia -37.8497  144.96800   10
# 4          Australia -37.8497  144.96800   10
# ...              ...      ...        ...  ...
# 10985             UK  52.0786   -1.01694  153
# 10986             UK  52.0786   -1.01694  153
# 10987             UK  52.0786   -1.01694  153
# 10988             UK  52.0786   -1.01694  153
# 10989             UK  52.0786   -1.01694  153
#
#                                               circuitUrl          driverName  \
# 0      http://en.wikipedia.org/wiki/Melbourne_Grand_P...   Jaime Alguersuari
# 1      http://en.wikipedia.org/wiki/Melbourne_Grand_P...  Michael Schumacher
# 2      http://en.wikipedia.org/wiki/Melbourne_Grand_P...         Mark Webber
# 3      http://en.wikipedia.org/wiki/Melbourne_Grand_P...     Fernando Alonso
# 4      http://en.wikipedia.org/wiki/Melbourne_Grand_P...        Felipe Massa
# ...                                                  ...                 ...
# 10985   http://en.wikipedia.org/wiki/Silverstone_Circuit     Nico Hülkenberg
# 10986   http://en.wikipedia.org/wiki/Silverstone_Circuit        Lance Stroll
# 10987   http://en.wikipedia.org/wiki/Silverstone_Circuit        Esteban Ocon
# 10988   http://en.wikipedia.org/wiki/Silverstone_Circuit        Sergio Pérez
# 10989   http://en.wikipedia.org/wiki/Silverstone_Circuit        Carlos Sainz
#
#       constructorId constructorName
# 0                 5      Toro Rosso
# 1               131        Mercedes
# 2                 9        Red Bull
# 3                 6         Ferrari
# 4                 6         Ferrari
# ...             ...             ...
# 10985           210    Haas F1 Team
# 10986           117    Aston Martin
# 10987           214  Alpine F1 Team
# 10988             9        Red Bull
# 10989             6         Ferrari
#
# [10990 rows x 36 columns]

# %%
# Perform the groupby operation on a subset of columns from newPitStops,
# including the required raceId, driverId, constructorName, and driverName,
# and then merging the result with newResults

# First, calculate the sum of pit stop durations for each race, driver, and constructor
pitStopSummary = newPitStops.groupby(by=['raceId','driverId','constructorName','driverName'])['milliseconds'].sum().reset_index()

# Then, merge the summary with newResults
raceResults = pd.merge(newResults,pitStopSummary,left_on=['raceId','driverId','constructorName','driverName'],right_on=['raceId','driverId','constructorName','driverName'],how='left')

# Correct the column names used in the calculation:
# 'milliseconds' from pitStopSummary is now 'milliseconds_y' in raceResults
# 'milliseconds' from newResults is now 'milliseconds_x' in raceResults
raceResults['pitPercentage'] = raceResults['milliseconds_y']/raceResults['milliseconds_x']*100
raceResults
# Out:
#        raceId  driverId  constructorId  number_x  grid  position positionText  \
# 0          18         1              1      22.0     1       1.0            1
# 1          18         2              2       3.0     5       2.0            2
# 2          18         3              3       7.0     7       3.0            3
# 3          18         4              4       5.0    11       4.0            4
# 4          18         5              1      23.0     3       5.0            5
# ...       ...       ...            ...       ...   ...       ...          ...
# 26514    1132       839            214      31.0    18      16.0           16
# 26515    1132       815              9      11.0     0      17.0           17
# 26516    1132       855             15      24.0    14      18.0           18
# 26517    1132       847            131      63.0     1       NaN            R
# 26518    1132       842            214      10.0    19       NaN            W
#
#        positionOrder  points  laps  ... number_y  code  forename     surname  \
# 0                  1    10.0    58  ...     44.0   HAM     Lewis    Hamilton
# 1                  2     8.0    58  ...      NaN   HEI      Nick    Heidfeld
# 2                  3     6.0    58  ...      6.0   ROS      Nico     Rosberg
# 3                  4     5.0    58  ...     14.0   ALO  Fernando      Alonso
# 4                  5     4.0    58  ...      NaN   KOV    Heikki  Kovalainen
# ...              ...     ...   ...  ...      ...   ...       ...         ...
# 26514             16     0.0    50  ...     31.0   OCO   Esteban        Ocon
# 26515             17     0.0    50  ...     11.0   PER    Sergio       Pérez
# 26516             18     0.0    50  ...     24.0   ZHO    Guanyu        Zhou
# 26517             19     0.0    33  ...     63.0   RUS    George     Russell
# 26518             20     0.0     0  ...     10.0   GAS    Pierre       Gasly
#
#               dob  driverNationality  \
# 0      1985-01-07            British
# 1      1977-05-10             German
# 2      1985-06-27             German
# 3      1981-07-29            Spanish
# 4      1981-10-19            Finnish
# ...           ...                ...
# 26514  1996-09-17             French
# 26515  1990-01-26            Mexican
# 26516  1999-05-30            Chinese
# 26517  1998-02-15            British
# 26518  1996-02-07             French
#
#                                                driverUrl         driverName  \
# 0            http://en.wikipedia.org/wiki/Lewis_Hamilton     Lewis Hamilton
# 1             http://en.wikipedia.org/wiki/Nick_Heidfeld      Nick Heidfeld
# 2              http://en.wikipedia.org/wiki/Nico_Rosberg       Nico Rosberg
# 3           http://en.wikipedia.org/wiki/Fernando_Alonso    Fernando Alonso
# 4         http://en.wikipedia.org/wiki/Heikki_Kovalainen  Heikki Kovalainen
# ...                                                  ...                ...
# 26514          http://en.wikipedia.org/wiki/Esteban_Ocon       Esteban Ocon
# 26515     http://en.wikipedia.org/wiki/Sergio_P%C3%A9rez       Sergio Pérez
# 26516           http://en.wikipedia.org/wiki/Zhou_Guanyu        Guanyu Zhou
# 26517  http://en.wikipedia.org/wiki/George_Russell_(r...     George Russell
# 26518          http://en.wikipedia.org/wiki/Pierre_Gasly       Pierre Gasly
#
#        milliseconds_y  pitPercentage
# 0                 NaN            NaN
# 1                 NaN            NaN
# 2                 NaN            NaN
# 3                 NaN            NaN
# 4                 NaN            NaN
# ...               ...            ...
# 26514        115146.0            NaN
# 26515        118875.0            NaN
# 26516        121224.0            NaN
# 26517         32045.0            NaN
# 26518             NaN            NaN
#
# [26519 rows x 58 columns]

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## How did pit stop durations change over time?
#
# Main observations
# * Average pit times had a meaningful increase from 2013 to 2014
# * Average pit times have been fairly stable from 2014 onwards
# * Majority of pit times are clustered around 20-35s
# * Pit durations appear to have more variance in the recent years

# %%
fig = px.line(
    newPitStops[newPitStops['seconds'] < 50]
    .assign(seconds=lambda df: pd.to_timedelta(df['time']).dt.total_seconds()) # Convert 'time' to seconds
    .groupby(by=['year', 'constructorName'])['seconds'].mean() #Calculate mean on numeric column
    .reset_index(),
    x='year',
    y='seconds',
    color='constructorName',
    color_discrete_map=constructor_color_map,
)
fig.update_layout(title_text='Average Pit Stop Durations by Constructor')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="30efac2a-355c-4806-bdcb-87aa81830a9b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("30efac2a-355c-4806-bdcb-87aa81830a9b")) {                    Plotly.newPlot(                        "30efac2a-355c-4806-bdcb-87aa81830a9b",                        [{"hovertemplate":"constructorName=Ferrari\u003cbr\u003eyear=%{x}\u003cbr\u003eseconds=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Ferrari","line":{"color":"#ED1C24","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Ferrari","orientation":"v","showlegend":true,"x":[2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[39950.0,40266.666666666664,40054.945054945056,43740.0,43800.0,43473.417721518985,45337.5,47467.92452830189,45969.86301369863,47060.377358490565,51400.0,51090.41095890411,48417.391304347824,45810.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"constructorName=Force India\u003cbr\u003eyear=%{x}\u003cbr\u003eseconds=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Force India","line":{"color":"#FF80C7","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Force India","orientation":"v","showlegend":true,"x":[2011,2012,2013,2014,2015,2016,2017,2018],"xaxis":"x","y":[40138.14432989691,41470.12987012987,40740.84507042253,41265.67164179104,42840.0,42058.53658536585,42218.181818181816,46984.61538461538],"yaxis":"y","type":"scatter"},{"hovertemplate":"constructorName=HRT\u003cbr\u003eyear=%{x}\u003cbr\u003eseconds=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"HRT","line":{"color":"#b2945e","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"HRT","orientation":"v","showlegend":true,"x":[2011,2012],"xaxis":"x","y":[40207.5,42035.294117647056],"yaxis":"y","type":"scatter"},{"hovertemplate":"constructorName=Lotus\u003cbr\u003eyear=%{x}\u003cbr\u003eseconds=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Lotus","line":{"color":"#FFB800","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Lotus","orientation":"v","showlegend":true,"x":[2011],"xaxis":"x","y":[39621.42857142857],"yaxis":"y","type":"scatter"},{"hovertemplate":"constructorName=McLaren\u003cbr\u003eyear=%{x}\u003cbr\u003eseconds=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"McLaren","line":{"color":"#F58020","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"McLaren","orientation":"v","showlegend":true,"x":[2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[39845.454545454544,39833.76623376623,38787.80487804878,42615.0,44650.0,42428.57142857143,41783.60655737705,47207.142857142855,46600.0,47207.142857142855,51572.72727272727,50238.46153846154,50312.19512195122,44431.57894736842],"yaxis":"y","type":"scatter"},{"hovertemplate":"constructorName=Mercedes\u003cbr\u003eyear=%{x}\u003cbr\u003eseconds=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Mercedes","line":{"color":"#6CD3BF","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Mercedes","orientation":"v","showlegend":true,"x":[2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[40555.102040816324,42907.5,39956.043956043955,43881.08108108108,43728.0,42264.93506493507,44243.47826086957,48666.666666666664,46808.9552238806,47754.098360655735,51936.0,50636.84210526316,49005.0,45000.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"constructorName=Red Bull\u003cbr\u003eyear=%{x}\u003cbr\u003eseconds=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Red Bull","line":{"color":"#1E5BC6","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Red Bull","orientatio ...

# %%
fig = px.scatter(newPitStops[newPitStops['seconds']<50],
                 x='date',
                 y='seconds',
                 color='constructorName',
                 color_discrete_map=constructor_color_map,
                )
fig.update_layout(
    title_text='Pit Stop Durations over Time by Constructor',
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d18bb27a-cee3-4f7a-82c1-5711dc21aa22" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d18bb27a-cee3-4f7a-82c1-5711dc21aa22")) {                    Plotly.newPlot(                        "d18bb27a-cee3-4f7a-82c1-5711dc21aa22",                        [{"hovertemplate":"constructorName=Toro Rosso\u003cbr\u003edate=%{x}\u003cbr\u003eseconds=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Toro Rosso","marker":{"color":"#0000FF","symbol":"circle"},"mode":"markers","name":"Toro Rosso","showlegend":true,"x":["2011-03-27T00:00:00","2011-03-27T00:00:00","2011-03-27T00:00:00","2011-03-27T00:00:00","2011-03-27T00:00:00","2011-04-10T00:00:00","2011-04-10T00:00:00","2011-04-10T00:00:00","2011-04-10T00:00:00","2011-04-10T00:00:00","2011-04-17T00:00:00","2011-04-17T00:00:00","2011-04-17T00:00:00","2011-04-17T00:00:00","2011-05-08T00:00:00","2011-05-08T00:00:00","2011-05-08T00:00:00","2011-05-08T00:00:00","2011-05-08T00:00:00","2011-05-08T00:00:00","2011-05-08T00:00:00","2011-05-22T00:00:00","2011-05-22T00:00:00","2011-05-22T00:00:00","2011-05-22T00:00:00","2011-05-22T00:00:00","2011-05-22T00:00:00","2011-05-22T00:00:00","2011-05-29T00:00:00","2011-05-29T00:00:00","2011-05-29T00:00:00","2011-05-29T00:00:00","2011-06-12T00:00:00","2011-06-12T00:00:00","2011-06-12T00:00:00","2011-06-12T00:00:00","2011-06-12T00:00:00","2011-06-12T00:00:00","2011-06-12T00:00:00","2011-06-26T00:00:00","2011-06-26T00:00:00","2011-06-26T00:00:00","2011-06-26T00:00:00","2011-06-26T00:00:00","2011-07-10T00:00:00","2011-07-10T00:00:00","2011-07-10T00:00:00","2011-07-10T00:00:00","2011-07-24T00:00:00","2011-07-24T00:00:00","2011-07-24T00:00:00","2011-07-24T00:00:00","2011-07-31T00:00:00","2011-07-31T00:00:00","2011-07-31T00:00:00","2011-07-31T00:00:00","2011-07-31T00:00:00","2011-07-31T00:00:00","2011-09-11T00:00:00","2011-09-11T00:00:00","2011-09-11T00:00:00","2011-09-11T00:00:00","2011-09-25T00:00:00","2011-09-25T00:00:00","2011-09-25T00:00:00","2011-09-25T00:00:00","2011-09-25T00:00:00","2011-09-25T00:00:00","2011-10-09T00:00:00","2011-10-09T00:00:00","2011-10-09T00:00:00","2011-10-16T00:00:00","2011-10-16T00:00:00","2011-10-16T00:00:00","2011-10-16T00:00:00","2011-10-30T00:00:00","2011-10-30T00:00:00","2011-10-30T00:00:00","2011-11-13T00:00:00","2011-11-13T00:00:00","2011-11-27T00:00:00","2011-11-27T00:00:00","2011-11-27T00:00:00","2011-11-27T00:00:00","2012-03-18T00:00:00","2012-03-18T00:00:00","2012-03-18T00:00:00","2012-03-18T00:00:00","2012-03-18T00:00:00","2012-03-25T00:00:00","2012-03-25T00:00:00","2012-03-25T00:00:00","2012-03-25T00:00:00","2012-03-25T00:00:00","2012-03-25T00:00:00","2012-04-15T00:00:00","2012-04-15T00:00:00","2012-04-15T00:00:00","2012-04-15T00:00:00","2012-04-15T00:00:00","2012-04-22T00:00:00","2012-04-22T00:00:00","2012-04-22T00:00:00","2012-04-22T00:00:00","2012-04-22T00:00:00","2012-04-22T00:00:00","2012-05-13T00:00:00","2012-05-13T00:00:00","2012-05-13T00:00:00","2012-05-13T00:00:00","2012-05-13T00:00:00","2012-05-13T00:00:00","2012-05-27T00:00:00","2012-05-27T00:00:00","2012-05-27T00:00:00","2012-06-10T00:00:00","2012-06-10T00:00:00","2012-06-10T00:00:00","2012-06-10T00:00:00","2012-06-10T00:00:00","2012-06-24T00:00:00","2012-06-24T00:00:00","2012-06-24T00:00:00","2012-07-08T00:00:00","2012-07-08T00:00:00","2012-07-08T00:00:00","2012-07-08T00:00:00","2012-07-22T00:00:00","2012-07-22T00:00:00","2012-07-22T00:00:00","2012-07-22T00:00:00","2012-07-22T00:00:00","2012-07-29T00:00:00","2012-07-29T00:00:00","2012-07-29T00:00:00","2012-07-29T00:00:00","2012-07-29T00:00:00","2012-07-29T00:00:00","2012-07-29T00:00:00","2012-09-02T00:00:00","2012-09-02T00:00:00","2012-09-02T00:00:00","2012-09-02T00:00:00","2012-09-09T00:00:00" ...

# %%
fig = px.box(newPitStops[newPitStops['seconds']<50],
                 x='date',
                 y='seconds',
                 color='constructorName',
                 color_discrete_map=constructor_color_map,
                )
fig.update_layout(
    title_text='Pit Stop Durations over Time by Constructor',
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c13637a3-e3e4-46cb-803c-617e21fa5bf9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c13637a3-e3e4-46cb-803c-617e21fa5bf9")) {                    Plotly.newPlot(                        "c13637a3-e3e4-46cb-803c-617e21fa5bf9",                        [{"alignmentgroup":"True","hovertemplate":"constructorName=Toro Rosso\u003cbr\u003edate=%{x}\u003cbr\u003eseconds=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Toro Rosso","marker":{"color":"#0000FF"},"name":"Toro Rosso","notched":false,"offsetgroup":"Toro Rosso","orientation":"v","showlegend":true,"x":["2011-03-27T00:00:00","2011-03-27T00:00:00","2011-03-27T00:00:00","2011-03-27T00:00:00","2011-03-27T00:00:00","2011-04-10T00:00:00","2011-04-10T00:00:00","2011-04-10T00:00:00","2011-04-10T00:00:00","2011-04-10T00:00:00","2011-04-17T00:00:00","2011-04-17T00:00:00","2011-04-17T00:00:00","2011-04-17T00:00:00","2011-05-08T00:00:00","2011-05-08T00:00:00","2011-05-08T00:00:00","2011-05-08T00:00:00","2011-05-08T00:00:00","2011-05-08T00:00:00","2011-05-08T00:00:00","2011-05-22T00:00:00","2011-05-22T00:00:00","2011-05-22T00:00:00","2011-05-22T00:00:00","2011-05-22T00:00:00","2011-05-22T00:00:00","2011-05-22T00:00:00","2011-05-29T00:00:00","2011-05-29T00:00:00","2011-05-29T00:00:00","2011-05-29T00:00:00","2011-06-12T00:00:00","2011-06-12T00:00:00","2011-06-12T00:00:00","2011-06-12T00:00:00","2011-06-12T00:00:00","2011-06-12T00:00:00","2011-06-12T00:00:00","2011-06-26T00:00:00","2011-06-26T00:00:00","2011-06-26T00:00:00","2011-06-26T00:00:00","2011-06-26T00:00:00","2011-07-10T00:00:00","2011-07-10T00:00:00","2011-07-10T00:00:00","2011-07-10T00:00:00","2011-07-24T00:00:00","2011-07-24T00:00:00","2011-07-24T00:00:00","2011-07-24T00:00:00","2011-07-31T00:00:00","2011-07-31T00:00:00","2011-07-31T00:00:00","2011-07-31T00:00:00","2011-07-31T00:00:00","2011-07-31T00:00:00","2011-09-11T00:00:00","2011-09-11T00:00:00","2011-09-11T00:00:00","2011-09-11T00:00:00","2011-09-25T00:00:00","2011-09-25T00:00:00","2011-09-25T00:00:00","2011-09-25T00:00:00","2011-09-25T00:00:00","2011-09-25T00:00:00","2011-10-09T00:00:00","2011-10-09T00:00:00","2011-10-09T00:00:00","2011-10-16T00:00:00","2011-10-16T00:00:00","2011-10-16T00:00:00","2011-10-16T00:00:00","2011-10-30T00:00:00","2011-10-30T00:00:00","2011-10-30T00:00:00","2011-11-13T00:00:00","2011-11-13T00:00:00","2011-11-27T00:00:00","2011-11-27T00:00:00","2011-11-27T00:00:00","2011-11-27T00:00:00","2012-03-18T00:00:00","2012-03-18T00:00:00","2012-03-18T00:00:00","2012-03-18T00:00:00","2012-03-18T00:00:00","2012-03-25T00:00:00","2012-03-25T00:00:00","2012-03-25T00:00:00","2012-03-25T00:00:00","2012-03-25T00:00:00","2012-03-25T00:00:00","2012-04-15T00:00:00","2012-04-15T00:00:00","2012-04-15T00:00:00","2012-04-15T00:00:00","2012-04-15T00:00:00","2012-04-22T00:00:00","2012-04-22T00:00:00","2012-04-22T00:00:00","2012-04-22T00:00:00","2012-04-22T00:00:00","2012-04-22T00:00:00","2012-05-13T00:00:00","2012-05-13T00:00:00","2012-05-13T00:00:00","2012-05-13T00:00:00","2012-05-13T00:00:00","2012-05-13T00:00:00","2012-05-27T00:00:00","2012-05-27T00:00:00","2012-05-27T00:00:00","2012-06-10T00:00:00","2012-06-10T00:00:00","2012-06-10T00:00:00","2012-06-10T00:00:00","2012-06-10T00:00:00","2012-06-24T00:00:00","2012-06-24T00:00:00","2012-06-24T00:00:00","2012-07-08T00:00:00","2012-07-08T00:00:00","2012-07-08T00:00:00","2012-07-08T00:00:00","2012-07-22T00:00:00","2012-07-22T00:00:00","2012-07-22T00:00:00","2012-07-22T00:00:00","2012-07-22T00:00:00","2012-07-29T00:00:00","2012-07-29T00:00:00","2012-07-29T00:00:00","2012-07-29T00:00:00","2012-07-29T00:00:00","2012-07-29T00:00:00","2012-07-29T00:00:00","2012-09-02T00:00:00","2012-09-02T00:00:00","2012-09-02T00: ...

# %% [markdown]
# ## Is there a relationship between pit stop durations and constructors?
#
# Main observations:
# * Constructors on average are fairly similar in pit durations
# * No significant performance discrepancy. Minor performance variations.

# %%
fig = px.box(newPitStops[newPitStops['seconds']<50]
             .assign(seconds=lambda df: pd.to_timedelta(df['time']).dt.total_seconds()) # Convert 'time' to total seconds if 'time' is a duration string
             .groupby(by=['raceId','date','constructorName']) # Removed 'raceName' from groupby keys
             .agg({'seconds': 'mean'}) # Explicitly specify 'seconds' column for mean calculation
             .reset_index()
             .sort_values(by='seconds',ascending=True),
             x='constructorName',
             y='seconds',
             color='constructorName',
             color_discrete_map=constructor_color_map,
            )
fig.update_layout(
    title_text='Pit Stop Durations by Constructor from 2011 to date',
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="0252a15c-05c1-430e-be90-1f98c89ec3cb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0252a15c-05c1-430e-be90-1f98c89ec3cb")) {                    Plotly.newPlot(                        "0252a15c-05c1-430e-be90-1f98c89ec3cb",                        [{"alignmentgroup":"True","hovertemplate":"constructorName=%{x}\u003cbr\u003eseconds=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Haas F1 Team","marker":{"color":"#B6BABD"},"name":"Haas F1 Team","notched":false,"offsetgroup":"Haas F1 Team","orientation":"v","showlegend":true,"x":["Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team","Haas F1 Team"],"x0":" ","xaxis":"x","y":[14400.0,18000.0,18000.0,18000.0,18000.0,18000.0,18000.0,18000.0,18000.0,18600.0,18600.0,18600.0,18600.0,21600.0,21600.0,21600.0,22200.0,22200.0,25200.0,25200.0,25200.0,36600.0,39600.0,39600.0,40200.0,40200.0,40200.0,43200.0,43200.0,43200.0,43200.0,43200.0,43200.0,43200.0,43200.0,43200.0,43200.0,43200.0,43200.0,43200.0,43200.0,43200.0,43200.0,43200.0,43200.0,43200.0,43200.0,43200.0,43200.0,43200.0,43200.0,43800.0,43800.0,43800.0,43800.0,43800.0,43800.0,46800.0,46800.0,46800.0,46800.0,46800.0,46800.0 ...

# %%
year = 2024
# Ensure 'raceName' column is present before groupby
if 'raceName' in newPitStops.columns:
    fig = px.box(newPitStops[(newPitStops['seconds']<50)&(newPitStops['year']==year)]
                 .groupby(by=['raceId','raceName','date','constructorName'])
                 .mean()
                 .reset_index()
                 .sort_values(by='seconds',ascending=True),
                 x='constructorName',
                 y='seconds',
                 color='constructorName',
                 color_discrete_map=constructor_color_map,
                )
    fig.update_layout(
        title_text=f'Pit Stop Durations by Constructor for {year} Season',
    )
    fig.show()
else:
    print("Column 'raceName' not found in DataFrame. Please check your data.")
# Out:
# Column 'raceName' not found in DataFrame. Please check your data.

# %% [markdown]
# ## Is there a relationship between pit stop durations and race circuit?
#
# Main Observations:
# * Race circuits appear to have a more significant impact on overall pit duration
# * Race circuits appear to have an impact on total pit time over the course of the race
# * Some circuits have larger variances, but on average the variance from track to track appear to be fairly consistent

# %%
# Check if 'raceName' column exists before groupby
if 'raceName' in newPitStops.columns:
    fig = px.box(newPitStops[newPitStops['seconds']<50].groupby(by=['raceId','raceName','circuitName']).mean().reset_index().sort_values(by='seconds',ascending=True),
                 x='circuitName',
                 y='seconds',
                )
    fig.update_layout(
        title_text='Pit Stop Durations by Race Circuit',
    )
    fig.show()
else:
    print("Column 'raceName' not found in DataFrame. Please check your data.")
# Out:
# Column 'raceName' not found in DataFrame. Please check your data.

# %%
fig = px.scatter(newPitStops[newPitStops['seconds']<50]
                 .assign(seconds=lambda df: pd.to_timedelta(df['time']).dt.total_seconds()) # Convert 'time' to total seconds if 'time' is a duration string
                 .groupby(by=['circuitName'])['seconds'].mean() # Select the 'seconds' column before calculating the mean
                 .reset_index()
                 .sort_values(by='seconds',ascending=True),
                 x='circuitName',
                 y='seconds',
                )
fig.update_layout(
    title_text='Average Race Pit Stop Durations by Circuit',
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="6b423411-b249-44eb-8a58-da69527210d8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6b423411-b249-44eb-8a58-da69527210d8")) {                    Plotly.newPlot(                        "6b423411-b249-44eb-8a58-da69527210d8",                        [{"hovertemplate":"circuitName=%{x}\u003cbr\u003eseconds=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":["Albert Park Grand Prix Circuit","Suzuka Circuit","Korean International Circuit","Las Vegas Strip Street Circuit","Shanghai International Circuit","Sepang International Circuit","Buddh International Circuit","Sochi Autodrom","Istanbul Park","Valencia Street Circuit","Marina Bay Street Circuit","Baku City Circuit","Nürburgring","Hungaroring","Circuit de Spa-Francorchamps","Circuit de Monaco","Circuit de Barcelona-Catalunya","Autodromo Nazionale di Monza","Hockenheimring","Red Bull Ring","Silverstone Circuit","Autodromo Enzo e Dino Ferrari","Circuit Park Zandvoort","Yas Marina Circuit","Autodromo Internazionale del Mugello","Circuit Paul Ricard","Autódromo Internacional do Algarve","Bahrain International Circuit","Losail International Circuit","Autódromo José Carlos Pace","Jeddah Corniche Circuit","Circuit Gilles Villeneuve","Circuit of the Americas","Autódromo Hermanos Rodríguez","Miami International Autodrome"],"xaxis":"x","y":[19472.727272727272,19712.47357293869,21600.0,21600.0,23485.714285714286,27696.774193548386,34200.0,41372.16494845361,41430.434782608696,43200.0,43261.62790697674,43813.04347826087,44204.34782608696,44489.36170212766,44545.578231292515,44687.93565683646,44724.737631184405,44863.71681415929,44882.87671232877,45715.33477321814,45844.61538461538,45981.818181818184,46800.0,46894.73684210526,47400.0,47898.87640449438,48458.82352941176,52031.02409638554,57342.857142857145,59353.99673735726,61495.890410958906,64215.980629539954,68608.06451612903,69285.84905660378,70890.4109589041],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type ...

# %%
# Check if all required columns exist before groupby
required_columns = ['raceId', 'raceName', 'circuitName', 'constructorName']
if all(col in newPitStops.columns for col in required_columns):
    fig = px.box(newPitStops[newPitStops['seconds'] < 50].groupby(by=required_columns).mean().reset_index().sort_values(by='seconds', ascending=True),
                 x='circuitName',
                 y='seconds',
                 color='constructorName',
                 color_discrete_map=constructor_color_map,
                 )
    fig.update_layout(
        title_text='Average Race Pit Stop Durations by Race Circuit',
    )
    fig.show()
else:
    missing_cols = [col for col in required_columns if col not in newPitStops.columns]
    print(f"Columns {missing_cols} not found in DataFrame. Please check your data.")
# Out:
# Columns ['raceName'] not found in DataFrame. Please check your data.

# %% [markdown]
# ## Total Time in the Pit Lane

# %%
# Instead of directly summing, select only numerical columns for the sum operation.
# This can be achieved by using the 'numeric_only=True' argument in the sum() function.
numeric_cols = newPitStops.select_dtypes(include=np.number).columns
# Instead of resetting the index, use the 'as_index=False' in the first groupby
# to keep the grouping columns as regular columns.
result = newPitStops[newPitStops['seconds'] < 50].groupby(by=['raceId', 'circuitName', 'driverId'], as_index=False)[numeric_cols].sum(numeric_only=True).groupby(by=['raceId', 'circuitName']).mean()
result
# Out:
#                                           driverId       stop         lap  \
# raceId circuitName
# 841    Albert Park Grand Prix Circuit   208.250000   1.000000   18.500000
# 842    Sepang International Circuit     415.000000   1.000000   15.000000
# 843    Shanghai International Circuit    96.000000   1.000000   16.000000
# 845    Circuit de Barcelona-Catalunya    24.000000   1.000000   16.000000
# 846    Circuit de Monaco                151.428571   1.000000   24.285714
# ...                                            ...        ...         ...
# 5820   Shanghai International Circuit  2484.000000  21.000000   87.500000
# 5892   Marina Bay Street Circuit       3769.500000  21.000000   84.250000
# 6120   Hockenheimring                  4950.000000  21.000000  202.000000
# 6588   Bahrain International Circuit   5076.000000  21.000000  192.000000
# 6666   Circuit Park Zandvoort          5092.000000  22.333333  201.666667
#
#                                         milliseconds     seconds     year  \
# raceId circuitName
# 841    Albert Park Grand Prix Circuit   23952.750000   23.952750   2011.0
# 842    Sepang International Circuit     24556.500000   24.556500   2011.0
# 843    Shanghai International Circuit   24234.000000   24.234000   2011.0
# 845    Circuit de Barcelona-Catalunya   23157.000000   23.157000   2011.0
# 846    Circuit de Monaco                28979.714286   28.979714   2011.0
# ...                                              ...         ...      ...
# 5820   Shanghai International Circuit  122066.000000  122.066000  12102.0
# 5892   Marina Bay Street Circuit       185480.250000  185.480250  12102.0
# 6120   Hockenheimring                  125009.000000  125.009000  12114.0
# 6588   Bahrain International Circuit   195334.000000  195.334000  12138.0
# 6666   Circuit Park Zandvoort          148328.666667  148.328667  12138.0
#
#                                        round  circuitId        lat        lng  \
# raceId circuitName
# 841    Albert Park Grand Prix Circuit    1.0        1.0  -37.84970  144.96800
# 842    Sepang International Circuit      2.0        2.0    2.76083  101.73800
# 843    Shanghai International Circuit    3.0       17.0   31.33890  121.22000
# 845    Circuit de Barcelona-Catalunya    5.0        4.0   41.57000    2.26111
# 846    Circuit de Monaco                 6.0        6.0   43.73470    7.42056
# ...                                      ...        ...        ...        ...
# 5820   Shanghai International Circuit   12.0      102.0  188.03340  727.32000
# 5892   Marina Bay Street Circuit        84.0       90.0    7.74840  623.18400
# 6120   Hockenheimring                   66.0       60.0  295.96680   51.39498
# 6588   Bahrain International Circuit     6.0       18.0  156.19500  303.06360
# 6666   Circuit Park Zandvoort           78.0      234.0  314.33280   27.24552
#
#                                          alt  constructorId
# raceId circuitName
# 841    Albert Park Grand Prix Circuit   10.0     129.250000
# 842    Sepang International Circuit     18.0     110.000000
# 843    Shanghai International Circuit    5.0      84.500000
# 845    Circuit de Barcelona-Catalunya  109.0     164.000000
# 846    Circuit de Monaco                 7.0      70.714286
# ...                                      ...            ...
# 5820   Shanghai International Circuit   30.0      39.000000
# 5892   Marina Bay Street Circuit       108.0     357.000000
# 6120   Hockenheimring                  618.0    1260.000000
# 6588   Bahrain International Circuit    42.0       6.000000
# 6666   Circuit Park Zandvoort           36.0     922.000000
#
# [784 rows x 12 columns]

# %%
# Instead of directly summing, select only numerical columns for the sum operation.
# This can be achieved by using the 'numeric_only=True' argument in the sum() function.
numeric_cols = newPitStops.select_dtypes(include=np.number).columns
# Instead of resetting the index, use the 'as_index=False' in the first groupby
# to keep the grouping columns as regular columns.
fig = px.box(newPitStops[newPitStops['seconds'] < 50].groupby(by=['raceId', 'circuitName', 'driverId'], as_index=False)[numeric_cols].sum(numeric_only=True).reset_index().sort_values(by='seconds', ascending=True),
             x='circuitName',
             y='seconds',
            )
fig.update_layout(
    title_text='Total Time Spent in Pit Lane by Circuit',
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="7b9c725a-da22-4d06-b05a-a39f62257663" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7b9c725a-da22-4d06-b05a-a39f62257663")) {                    Plotly.newPlot(                        "7b9c725a-da22-4d06-b05a-a39f62257663",                        [{"alignmentgroup":"True","hovertemplate":"circuitName=%{x}\u003cbr\u003eseconds=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["Albert Park Grand Prix Circuit","Autodromo Internazionale del Mugello","Albert Park Grand Prix Circuit","Albert Park Grand Prix Circuit","Albert Park Grand Prix Circuit","Albert Park Grand Prix Circuit","Albert Park Grand Prix Circuit","Albert Park Grand Prix Circuit","Circuit Gilles Villeneuve","Albert Park Grand Prix Circuit","Albert Park Grand Prix Circuit","Albert Park Grand Prix Circuit","Albert Park Grand Prix Circuit","Albert Park Grand Prix Circuit","Albert Park Grand Prix Circuit","Albert Park Grand Prix Circuit","Albert Park Grand Prix Circuit","Hockenheimring","Miami International Autodrome","Miami International Autodrome","Hockenheimring","Albert Park Grand Prix Circuit","Hockenheimring","Hockenheimring","Circuit Park Zandvoort","Miami International Autodrome","Miami International Autodrome","Albert Park Grand Prix Circuit","Yas Marina Circuit","Miami International Autodrome","Albert Park Grand Prix Circuit","Albert Park Grand Prix Circuit","Albert Park Grand Prix Circuit","Circuit Park Zandvoort","Miami International Autodrome","Circuit Park Zandvoort","Yas Marina Circuit","Circuit Park Zandvoort","Albert Park Grand Prix Circuit","Circuit Park Zandvoort","Yas Marina Circuit","Circuit Park Zandvoort","Yas Marina Circuit","Hockenheimring","Yas Marina Circuit","Miami International Autodrome","Circuit de Spa-Francorchamps","Miami International Autodrome","Circuit Park Zandvoort","Baku City Circuit","Baku City Circuit","Baku City Circuit","Baku City Circuit","Albert Park Grand Prix Circuit","Circuit Park Zandvoort","Miami International Autodrome","Yas Marina Circuit","Baku City Circuit","Baku City Circuit","Miami International Autodrome","Baku City Circuit","Circuit Park Zandvoort","Baku City Circuit","Jeddah Corniche Circuit","Baku City Circuit","Miami International Autodrome","Baku City Circuit","Circuit de Barcelona-Catalunya","Jeddah Corniche Circuit","Baku City Circuit","Circuit Gilles Villeneuve","Yas Marina Circuit","Korean International Circuit","Baku City Circuit","Yas Marina Circuit","Valencia Street Circuit","Baku City Circuit","Circuit Park Zandvoort","Baku City Circuit","Baku City Circuit","Baku City Circuit","Jeddah Corniche Circuit","Baku City Circuit","Baku City Circuit","Circuit Park Zandvoort","Jeddah Corniche Circuit","Baku City Circuit","Jeddah Corniche Circuit","Jeddah Corniche Circuit","Baku City Circuit","Jeddah Corniche Circuit","Baku City Circuit","Jeddah Corniche Circuit","Baku City Circuit","Circuit Park Zandvoort","Jeddah Corniche Circuit","Jeddah Corniche Circuit","Buddh International Circuit","Baku City Circuit","Jeddah Corniche Circuit","Jeddah Corniche Circuit","Jeddah Corniche Circuit","Baku City Circuit","Yas Marina Circuit","Jeddah Corniche Circuit","Autodromo Nazionale di Monza","Jeddah Corniche Circuit","Red Bull Ring","Jeddah Corniche Circuit","Yas Marina Circuit","Baku City Circuit","Baku City Circuit","Albert Park Grand Prix Circuit","Buddh International Circuit","Buddh International Circuit","Circuit de Spa-Francorchamps","Circuit of the Americas","Jeddah Corniche Circuit","Jeddah Corniche Circuit","Buddh International Circuit","Jeddah Corniche Circuit","Baku City Circuit" ...

# %% [markdown]
# ## Percentage of race spent in the pit lane
#
# Main Observations:
# * Findings from pit percentage unsurprisingly are very similar to the average pit time with its correlation to circuit
# * There doesn't appear to be much of a correlation between percentage of time in the pit and the race outcome
# * Pit percentage does not appear to yield any interesting insights

# %%
import plotly.express as px
import numpy as np
import pandas as pd
# Assuming 'raceResults' is your DataFrame and 'constructor_color_map' is defined
fig = px.box(
    raceResults[raceResults['pitPercentage'] < 10]
    .groupby(by=['raceId', 'circuitName', 'constructorName'], as_index=False)
    # Explicitly selecting numeric columns before calculating the mean
    .agg({col: 'mean' for col in raceResults.select_dtypes(include=np.number).columns})
    .reset_index()
    .sort_values(by='pitPercentage', ascending=True),
    x='circuitName',
    y='pitPercentage',
    color='constructorName',
    color_discrete_map=constructor_color_map,
)
fig.update_layout(
    title_text='Average Race Percentage in the Pit Lane by Race Circuit',
)
# Correcting the line for calculating and adding the average line
avg_pit_percentage = raceResults[raceResults['pitPercentage'] < 10]['pitPercentage'].mean()
fig.add_hline(
    y=avg_pit_percentage,
    line_dash='dash',
    annotation_text=f"Average pit percentage: {avg_pit_percentage:.2f}%"
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e2aa6f97-0581-4caa-b5fe-40c6c2261543" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e2aa6f97-0581-4caa-b5fe-40c6c2261543")) {                    Plotly.newPlot(                        "e2aa6f97-0581-4caa-b5fe-40c6c2261543",                        [{"alignmentgroup":"True","hovertemplate":"constructorName=Red Bull\u003cbr\u003ecircuitName=%{x}\u003cbr\u003epitPercentage=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Red Bull","marker":{"color":"#1E5BC6"},"name":"Red Bull","notched":false,"offsetgroup":"Red Bull","orientation":"v","showlegend":true,"x":["Circuit de Monaco","Albert Park Grand Prix Circuit","Yas Marina Circuit","Hungaroring","Circuit of the Americas","Yas Marina Circuit","Baku City Circuit","Autódromo Hermanos Rodríguez","Yas Marina Circuit","Circuit de Barcelona-Catalunya","Yas Marina Circuit","Buddh International Circuit","Baku City Circuit","Circuit de Monaco","Autódromo Hermanos Rodríguez","Circuit de Monaco","Albert Park Grand Prix Circuit","Circuit de Monaco","Circuit of the Americas","Autódromo Hermanos Rodríguez","Marina Bay Street Circuit","Circuit de Monaco","Circuit de Monaco","Jeddah Corniche Circuit","Istanbul Park","Albert Park Grand Prix Circuit","Circuit of the Americas","Circuit Gilles Villeneuve","Miami International Autodrome","Jeddah Corniche Circuit","Red Bull Ring","Red Bull Ring","Circuit Gilles Villeneuve","Circuit Gilles Villeneuve","Marina Bay Street Circuit","Albert Park Grand Prix Circuit","Circuit de Spa-Francorchamps","Jeddah Corniche Circuit","Suzuka Circuit","Red Bull Ring","Sepang International Circuit","Autódromo José Carlos Pace","Circuit Paul Ricard","Circuit de Spa-Francorchamps","Marina Bay Street Circuit","Silverstone Circuit","Autodromo Nazionale di Monza","Autódromo Internacional do Algarve","Circuit Gilles Villeneuve","Miami International Autodrome","Suzuka Circuit","Autodromo Nazionale di Monza","Autodromo Nazionale di Monza","Sochi Autodrom","Autodromo Nazionale di Monza","Autodromo Nazionale di Monza","Sochi Autodrom","Sochi Autodrom","Autodromo Nazionale di Monza","Autódromo Hermanos Rodríguez","Yas Marina Circuit","Sochi Autodrom","Silverstone Circuit","Hungaroring","Circuit de Monaco","Circuit de Spa-Francorchamps","Circuit de Monaco","Autodromo Enzo e Dino Ferrari","Autódromo Hermanos Rodríguez","Circuit Paul Ricard","Circuit de Monaco","Circuit de Monaco","Marina Bay Street Circuit","Miami International Autodrome","Yas Marina Circuit","Sochi Autodrom","Red Bull Ring","Red Bull Ring","Hockenheimring","Valencia Street Circuit","Red Bull Ring","Circuit Paul Ricard","Korean International Circuit","Korean International Circuit","Circuit Park Zandvoort","Yas Marina Circuit","Hungaroring","Albert Park Grand Prix Circuit","Hungaroring","Hungaroring","Autódromo Hermanos Rodríguez","Yas Marina Circuit","Baku City Circuit","Yas Marina Circuit","Yas Marina Circuit","Shanghai International Circuit","Korean International Circuit","Autódromo Hermanos Rodríguez","Hungaroring","Circuit de Barcelona-Catalunya","Hungaroring","Shanghai International Circuit","Circuit Gilles Villeneuve","Circuit Gilles Villeneuve","Nürburgring","Baku City Circuit","Circuit de Barcelona-Catalunya","Circuit Gilles Villeneuve","Circuit de Barcelona-Catalunya","Sochi Autodrom","Buddh International Circuit","Circuit de Barcelona-Catalunya","Circuit Gilles Villeneuve","Shanghai International Circuit","Shanghai International Circuit","Circuit of the Americas","Red Bull Ring","Marina Bay Street Circuit","Albert Park Grand Prix Circuit","Marina Bay Street Circuit","Yas Marina Circuit","Hungaroring","Circuit Gilles Villeneuve","Circuit de Barcelona-Catalunya","Circuit Gilles Villeneuve"," ...

# %%
# Use as_index=False in the groupby to avoid raceId, circuitName, and constructorName
# becoming part of the index. This will prevent the conflict when using reset_index().
fig = px.scatter(raceResults[raceResults['pitPercentage']<10].groupby(by=['raceId','circuitName','constructorName'], as_index=False)[raceResults.select_dtypes(include=np.number).columns].mean(),
                 x='pitPercentage',
                 y='positionOrder',
                 color='constructorName',
                 color_discrete_map=constructor_color_map,
                )

# %% [markdown]
# ## What is a "good" pit stop?
#
# After exploring some relationships that pit stops might have with other features, the circuit has a meaningful effect to the pit times measured. To get a good reference on what a "good" pit stop is, we can take a look at the distribution of all the pit stops available.
#
# There may be some minor normalization based on the circuit to provide a more meaningful comparison with respect to a particular pit time.

# %%
fig = px.histogram(newPitStops[(newPitStops['seconds']<50)],
                 x='seconds',

                )
fig.update_layout(
    title_text='Pit Stop Duration Distribution',
)
fig.add_vline(x=newPitStops[(newPitStops['seconds']<50)]['seconds'].mean(),annotation_text=f"Average: {newPitStops[(newPitStops['seconds']<50)]['seconds'].mean():.2f}s")
fig.add_vline(x=newPitStops[(newPitStops['seconds']<50)]['seconds'].quantile(0.1),line_dash='dash',annotation_text=f"Top Decile: {newPitStops[(newPitStops['seconds']<50)]['seconds'].quantile(0.1):.2f}s")
fig.add_vline(x=newPitStops[(newPitStops['seconds']<50)]['seconds'].quantile(0.9),line_dash='dash',annotation_text=f"Bottom Decile: {newPitStops[(newPitStops['seconds']<50)]['seconds'].quantile(0.9):.2f}s")
fig.update_traces(opacity=0.9)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b0270490-723c-4471-9911-d3b57becabf7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b0270490-723c-4471-9911-d3b57becabf7")) {                    Plotly.newPlot(                        "b0270490-723c-4471-9911-d3b57becabf7",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"seconds=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[26.898,25.021,23.426,23.251,23.842,23.643,22.603,24.863,25.259,25.342,22.994,23.227,24.535,23.716,24.064,25.978,24.899,16.867,24.463,24.865,23.988,23.792,23.303,23.438,37.856,22.52,24.733,16.892,23.1,25.098,24.5,24.192,24.036,23.199,26.348,25.683,24.332,22.681,23.871,24.848,26.446,26.23,26.309,24.181,24.095,31.694,32.978,22.572,22.773,22.552,23.019,23.9,22.4,29.224,25.516,23.152,22.576,23.182,23.28,24.967,29.084,23.584,22.046,23.28,23.597,24.617,26.252,27.815,24.502,29.843,21.991,22.471,22.611,22.419,21.893,23.894,23.221,22.541,22.68,22.261,22.577,22.069,22.888,22.55,27.439,23.336,24.429,24.416,23.442,25.382,23.977,22.483,22.893,22.602,26.554,22.526,22.313,23.812,22.227,22.161,28.694,27.182,38.823,22.466,22.419,14.16,20.522,23.442,23.16,21.989,20.771,22.01,23.779,21.995,21.855,21.624,20.878,20.989,22.524,21.473,21.709,24.722,22.683,21.981,22.216,22.485,23.029,22.901,24.467,26.049,20.758,22.005,20.533,21.132,22.062,21.964,21.908,21.058,21.936,21.821,21.533,21.251,21.218,21.168,21.928,22.802,21.481,23.397,21.237,22.005,20.567,20.72,21.4,21.091,33.827,21.89,27.62,22.26,23.499,28.708,13.9,28.845,29.27,30.182,21.422,22.022,20.833,21.769,21.05,21.308,22.573,22.3,22.717,21.649,20.623,20.775,23.881,21.368,21.82,22.713,23.066,20.907,27.353,22.854,24.634,22.895,22.779,21.323,21.075,20.421,20.927,21.919,21.732,21.322,22.128,23.455,22.868,20.93,20.112,21.084,22.555,22.862,22.639,24.962,21.826,20.379,21.633,20.887,22.365,20.949,35.688,24.837,21.838,23.471,20.843,21.702,20.872,25.125,22.456,21.417,21.986,20.385,22.219,22.032,21.687,21.006,43.603,21.827,21.715,20.308,21.403,22.087,21.662,20.597,21.379,13.925,22.041,21.884,26.685,20.489,24.474,23.114,21.931,24.871,23.592,22.689,20.253,20.818,20.567,20.881,20.084,19.761,21.856,20.647,20.8,20.741,29.936,20.773,20.015,24.843,20.07,22.364,21.019,23.157,22.744,23.176,19.887,20.238,20.079,24.821,21.635,21.322,20.235,21.226,20.872,24.745,21.128,20.487,24.232,19.534,20.738,20.279,20.807,21.143,21.723,24.448,20.763,20.267,20.126,20.426,20.473,22.982,20.65,22.419,21.574,21.953,21.019,20.38,21.632,20.451,21.739,23.068,20.395,20.819,23.001,20.5,19.984,20.292,21.829,20.107,20.988,23.23,24.298,20.796,23.143,21.708,20.573,22.077,21.17,20.637,35.084,25.28,25.189,28.536,37.735,25.352,26.477,24.97,31.445,26.827,25.595,26.468,26.615,28.325,19.36,28.856,25.907,25.921,26.421,47.226,25.851,26.073,31.382,25.31,28.298,27.577,28.642,25.037,39.917,19.347,26.065,24.67,26.977,25.878,25.116,25.687,26.269,27.55,25.045,26.464,27.879,25.675,26.281,23.65,27.202,14.501,23.305,24.052,23.893,23.105,23.571,23.949,24.143,24.472,26.348,23.868,22.986,26.045,25.066,44.037,24.943,23.872,29.546,24.649,24.886,24.196,30.497,24.655,22.832,22.923,24.425,24.684,23.97,23.113,22.479,23.589,30.288,24.863,23.593,34.897,23.687,22.742,23.816,22.402,26.129,22.735,23.332,14.538,22.958,29.115,31.718,28.63,14.565,32.449,22.77,23.059,26.561,14.538,23.741,23.338,23.7,25.079,29.54,22.869,22.56,23.364,24.039,25.14,30.714,22.526,33.278,24.618,24.145,22.702,28.346,23.129,31.701,21.301,22.114,21.163,23.492,20.34,21.054,20.676,20.465,21.006,21.477,20.997,21.201,20.567,21.321,23.241,28.03,20.718,22.104,30.665,24.459,21.9,23.327,21.943,21 ...

# %% [markdown]
# ### Circuit Specific Benchmarks
#
# Double click on the circuit to see the circuit specific pit time distribution.

# %%
fig = px.histogram(newPitStops[(newPitStops['seconds']<50)],
                 x='seconds',
                 color='circuitName',
                )
fig.update_layout(
    title_text='Pit Stop Duration Distribution by Circuit',
    barmode='overlay',
)
fig.add_vline(x=newPitStops[(newPitStops['seconds']<50)]['seconds'].mean(),annotation_text=f"Average: {newPitStops[(newPitStops['seconds']<50)]['seconds'].mean():.2f}s",annotation_position='top')
fig.add_vline(x=newPitStops[(newPitStops['seconds']<50)]['seconds'].quantile(0.1),line_dash='dash',annotation_text=f"Top Decile: {newPitStops[(newPitStops['seconds']<50)]['seconds'].quantile(0.1):.2f}s",annotation_position='top left')
fig.add_vline(x=newPitStops[(newPitStops['seconds']<50)]['seconds'].quantile(0.9),line_dash='dash',annotation_text=f"Bottom Decile: {newPitStops[(newPitStops['seconds']<50)]['seconds'].quantile(0.9):.2f}s",annotation_position='bottom right')
fig.update_traces(opacity=0.9)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c12e795e-eba5-4e48-b053-54a331add207" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c12e795e-eba5-4e48-b053-54a331add207")) {                    Plotly.newPlot(                        "c12e795e-eba5-4e48-b053-54a331add207",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"circuitName=Albert Park Grand Prix Circuit\u003cbr\u003eseconds=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Albert Park Grand Prix Circuit","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Albert Park Grand Prix Circuit","offsetgroup":"Albert Park Grand Prix Circuit","orientation":"v","showlegend":true,"x":[26.898,25.021,23.426,23.251,23.842,23.643,22.603,24.863,25.259,25.342,22.994,23.227,24.535,23.716,24.064,25.978,24.899,16.867,24.463,24.865,23.988,23.792,23.303,23.438,37.856,22.52,24.733,16.892,23.1,25.098,24.5,24.192,24.036,23.199,26.348,25.683,24.332,22.681,23.871,24.848,26.446,26.23,26.309,24.181,24.095,24.599,32.319,22.313,23.203,22.035,25.346,24.933,23.302,24.397,23.275,24.256,23.427,22.862,24.579,24.881,23.203,26.322,25.303,23.257,23.882,22.528,23.777,23.017,24.579,21.91,24.58,22.837,23.464,24.162,48.984,24.131,22.915,23.166,23.31,23.569,25.046,22.103,28.888,24.348,30.888,17.088,22.282,24.24,22.239,22.316,23.528,36.564,21.807,24.104,21.754,23.01,23.394,21.792,22.709,23.074,23.371,23.099,22.155,22.274,23.435,23.677,23.834,21.717,22.133,30.838,21.606,23.571,22.693,22.704,21.511,22.004,24.688,23.215,22.315,23.387,24.177,22.015,23.051,22.181,23.509,23.917,22.948,21.509,21.596,21.538,22.534,21.515,21.704,24.06,21.705,21.778,23.16,22.749,22.669,17.255,32.657,25.541,22.411,22.497,24.331,22.994,23.15,22.615,22.887,25.543,23.124,30.514,23.238,24.209,23.821,22.264,22.847,23.797,22.399,22.526,22.933,22.978,21.978,22.427,21.825,23.92,22.273,23.673,23.493,22.656,34.921,24.305,23.117,22.681,27.465,22.062,22.137,22.535,22.694,22.295,22.933,22.105,23.254,23.353,23.532,26.009,22.405,22.353,21.612,27.831,22.414,22.701,21.55,26.206,22.357,21.531,22.245,21.796,23.286,23.224,21.339,22.303,22.616,22.508,21.94,22.167,24.719,21.376,22.079,16.936,21.837,22.392,29.066,23.895,24.548,21.981,31.336,22.293,39.562,22.154,28.591,22.484,23.13,21.709,22.045,21.762,21.568,21.988,21.44,22.208,22.033,22.38,23.159,25.559,22.189,24.026,22.213,21.421,21.821,22.242,20.953,21.983,23.868,22.296,21.854,23.054,22.628,22.327,22.474,21.664,25.504,21.787,21.44,22.573,22.836,21.397,32.997,33.027,23.299,21.588,23.234,21.995,22.388,21.78,21.515,29.981,21.627,22.014,21.157,22.086,21.689,22.471,27.172,22.306,22.343,21.269,21.543,21.889,18.242,18.56,18.552,19.039,19.128,18.281,18.443,17.434,17.556,18.15,18.926,18.38,17.973,17.877,18.413,18.479,20.402,17.936,18.796,19.111,18.394,19.845,18.056,18.951,18.382,17.657,21.659,19.158,17.814,19.146,18.319,20.789,19.018,18.08,19.825,19.442,21.881,18.258,18.265,17.755,19.032,17.596,18.301,18.046,17.901,46.969,17.409,17.573,18.523,18.287,17.776,18.112,17.599,30.626,18.16,18.32,20.316,17.745,17.751,18.151,17.308,17.222,18.145,36.866,17.535,18.938,17.977,18.533,17.653,17.74,17.995,17.682,18.007,17.964],"xaxis":"x","yaxis":"y","type":"histogram","opacity":0.9},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"circuitName=Sepang International Circuit\u003cbr\u003eseconds=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Sepang International Circuit","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Sepang International Circuit","offsetgroup":"Sepang International Circuit","orientation":"v","showlegend":true,"x":[31.694,32.978,22.572,22.773,22.552,23.019,23.9,22.4,29.224,25.516,23.152,22.576,23.182,23.28,24.967,29.084,23.584, ...

# %% [markdown]
# # So who does it best?
#
# As far as performance is concerned, it seems like speed and consistency are the two main factors that indicate a great team. Average pit time will provide both an indication of speed and consistency as an expected performance metric. Obviously the lower average the better. Standard deviation is another aspect that we can look at to evaluate the consistency of a team's ability to perform.

# %% [markdown]
# ### Ranking on Average Pit Time

# %%
year = 2021
newPitStops[(newPitStops['seconds']<50)&(newPitStops['year']==year)].groupby(by='constructorName')['seconds'].describe().sort_values(by='mean')
# Out:
#                  count       mean       std     min      25%      50%  \
# constructorName
# Red Bull          78.0  23.978026  4.623024  15.277  21.3920  22.7440
# Mercedes          75.0  24.118133  4.659454  15.432  21.5555  22.6800
# Ferrari           63.0  24.301857  4.996534  15.092  21.5220  23.0640
# McLaren           66.0  24.527000  4.924235  14.994  21.4925  23.5255
# Aston Martin      66.0  24.799500  5.382271  14.945  21.4905  23.5500
# Williams          67.0  24.936910  5.009406  18.153  21.9615  23.6810
# Alpine F1 Team    61.0  24.983246  5.237372  15.432  21.4520  23.8440
# Alfa Romeo        68.0  25.003559  5.171887  14.881  21.7985  24.0195
# AlphaTauri        68.0  25.212441  5.380044  14.943  21.7500  24.3225
# Haas F1 Team      69.0  25.398290  5.636702  15.054  22.1130  24.2930
#
#                       75%     max
# constructorName
# Red Bull         25.38925  44.608
# Mercedes         25.50000  40.266
# Ferrari          26.37900  42.786
# McLaren          26.53250  38.267
# Aston Martin     26.13175  43.124
# Williams         26.50700  46.315
# Alpine F1 Team   29.11600  40.800
# Alfa Romeo       28.40050  37.190
# AlphaTauri       28.79725  40.740
# Haas F1 Team     27.18600  49.729

# %% [markdown]
# ### Ranking on Consistency

# %%
newPitStops[(newPitStops['seconds']<50)&(newPitStops['year']==year)].groupby(by='constructorName')['seconds'].describe().sort_values(by='std')
# Out:
#                  count       mean       std     min      25%      50%  \
# constructorName
# Red Bull          78.0  23.978026  4.623024  15.277  21.3920  22.7440
# Mercedes          75.0  24.118133  4.659454  15.432  21.5555  22.6800
# McLaren           66.0  24.527000  4.924235  14.994  21.4925  23.5255
# Ferrari           63.0  24.301857  4.996534  15.092  21.5220  23.0640
# Williams          67.0  24.936910  5.009406  18.153  21.9615  23.6810
# Alfa Romeo        68.0  25.003559  5.171887  14.881  21.7985  24.0195
# Alpine F1 Team    61.0  24.983246  5.237372  15.432  21.4520  23.8440
# AlphaTauri        68.0  25.212441  5.380044  14.943  21.7500  24.3225
# Aston Martin      66.0  24.799500  5.382271  14.945  21.4905  23.5500
# Haas F1 Team      69.0  25.398290  5.636702  15.054  22.1130  24.2930
#
#                       75%     max
# constructorName
# Red Bull         25.38925  44.608
# Mercedes         25.50000  40.266
# McLaren          26.53250  38.267
# Ferrari          26.37900  42.786
# Williams         26.50700  46.315
# Alfa Romeo       28.40050  37.190
# Alpine F1 Team   29.11600  40.800
# AlphaTauri       28.79725  40.740
# Aston Martin     26.13175  43.124
# Haas F1 Team     27.18600  49.729

# %% [markdown]
# ### Constructor Specific Performance

# %%
fig = px.histogram(newPitStops[(newPitStops['seconds']<50)&(newPitStops['year']==year)],
                 x='seconds',
                 color='constructorName',
                 color_discrete_map=constructor_color_map,
                )
fig.update_layout(
    title_text='Pit Stop Duration Distribution by Constructor',
    barmode='overlay',
)
fig.add_vline(x=newPitStops[(newPitStops['seconds']<50)]['seconds'].mean(),annotation_text=f"Average: {newPitStops[(newPitStops['seconds']<50)]['seconds'].mean():.2f}s",annotation_position='top')
fig.add_vline(x=newPitStops[(newPitStops['seconds']<50)]['seconds'].quantile(0.1),line_dash='dash',annotation_text=f"Top Decile: {newPitStops[(newPitStops['seconds']<50)]['seconds'].quantile(0.1):.2f}s",annotation_position='top left')
fig.add_vline(x=newPitStops[(newPitStops['seconds']<50)]['seconds'].quantile(0.9),line_dash='dash',annotation_text=f"Bottom Decile: {newPitStops[(newPitStops['seconds']<50)]['seconds'].quantile(0.9):.2f}s",annotation_position='bottom right')

fig.update_traces(opacity=0.5)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="827f408a-5cea-481a-b61e-7c3e4dfc17a6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("827f408a-5cea-481a-b61e-7c3e4dfc17a6")) {                    Plotly.newPlot(                        "827f408a-5cea-481a-b61e-7c3e4dfc17a6",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"constructorName=Red Bull\u003cbr\u003eseconds=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Red Bull","marker":{"color":"#1E5BC6","pattern":{"shape":""}},"name":"Red Bull","offsetgroup":"Red Bull","orientation":"v","showlegend":true,"x":[23.993,24.767,24.105,24.191,23.848,29.809,44.608,22.718,21.89,22.104,22.1,26.743,26.607,26.319,23.565,22.382,21.345,21.592,23.746,24.548,19.769,21.874,15.277,29.803,29.682,30.123,23.477,20.936,20.961,21.09,21.735,21.236,27.892,27.848,29.082,22.569,35.245,21.047,20.848,19.287,19.142,18.578,18.555,32.456,23.906,29.578,36.026,31.017,32.313,22.442,22.463,23.727,25.018,24.052,23.604,21.908,22.114,17.916,18.308,17.807,18.136,22.722,23.165,22.766,22.656,22.916,25.3,25.419,25.175,25.42,25.465,20.71,21.152,21.471,21.871,21.413,21.453,21.385],"xaxis":"x","yaxis":"y","type":"histogram","opacity":0.5},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"constructorName=AlphaTauri\u003cbr\u003eseconds=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"AlphaTauri","marker":{"color":"#4E7C9B","pattern":{"shape":""}},"name":"AlphaTauri","offsetgroup":"AlphaTauri","orientation":"v","showlegend":true,"x":[38.338,25.046,24.317,24.328,24.983,31.068,30.696,32.277,21.353,22.266,22.319,22.542,26.202,26.172,28.042,26.065,24.428,24.43,20.253,20.156,15.085,14.943,30.226,30.781,21.234,21.145,22.564,20.85,26.604,28.685,29.134,28.18,40.74,39.839,21.819,21.295,21.543,19.163,19.85,30.112,29.354,30.98,30.972,31.915,23.329,29.31,23.802,23.745,23.529,22.549,31.939,17.758,19.439,17.711,18.608,18.499,23.116,35.416,23.039,25.659,25.63,26.674,26.109,27.874,22.455,22.133,21.909,21.92],"xaxis":"x","yaxis":"y","type":"histogram","opacity":0.5},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"constructorName=Alpine F1 Team\u003cbr\u003eseconds=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Alpine F1 Team","marker":{"color":"#2293D1","pattern":{"shape":""}},"name":"Alpine F1 Team","offsetgroup":"Alpine F1 Team","orientation":"v","showlegend":true,"x":[24.373,25.226,24.775,24.471,30.866,30.652,30.864,30.701,21.275,21.452,22.24,21.621,27.033,26.442,22.043,22.798,23.479,23.935,23.803,20.168,19.983,15.432,31.288,30.207,21.131,21.238,22.663,28.772,29.743,39.522,37.122,21.642,21.523,19.24,19.018,24.797,30.333,29.901,30.157,30.702,33.264,29.116,40.8,23.576,23.919,23.844,23.314,23.1,23.985,19.285,17.751,17.818,17.705,23.504,24.375,25.991,25.517,20.405,21.097,21.677,21.304],"xaxis":"x","yaxis":"y","type":"histogram","opacity":0.5},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"constructorName=McLaren\u003cbr\u003eseconds=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"McLaren","marker":{"color":"#F58020","pattern":{"shape":""}},"name":"McLaren","offsetgroup":"McLaren","orientation":"v","showlegend":true,"x":[24.899,24.688,24.655,25.64,34.34,30.654,21.407,21.965,22.551,22.355,26.952,28.639,21.864,22.406,21.762,22.467,23.874,24.715,20.533,20.082,15.866,14.994,29.951,30.531,21.692,21.41,21.151,26.474,28.817,31.706,38.267,34.492,21.623,19.449,20.443,23.812,24.168,33.617,29.824,31.016,32.67,23.028,23.239,24.385,24.176,24.036,25.548,38.128,22.813,22.534,27.313,17.719,19.732,17.673,18.347,19.176,22.839,24.211,25.319,25.562,26.552,20.973,21.38,21.449,22.173,22.056],"xaxis":"x" ...

# %% [markdown]
# # Conclusions
#
# Pit stops are cool and play an integral part of the F1 sport, but optimizing it is probably a waste of time (at least in today's state). The pit time on average accounts for less than 1% of the race time (0.83%). Your efforts are likely better spent in other areas.
#
# ### How did pit stop durations change over time?
# Average pit stops have increased since 2013 and have stayed relatively similar since then. Pit stop times have also increased in variance over the past couple years as well
#
# ### Is there a relationship between pit stop durations and constructor?
# Not meaningful. There are some differences between the constructors; however, it doesn't appear to make a significant results on the race outcome.
#
# ### Is there a relationship between pit stop durations and race circuit?
# Yes. The circuits have an impact on the overall time spent in the pit lane. Either by the number of stops, track layout, or the length of pit lane.
#
# ### What is the time spent in the pit lane as a percentage of the race?
# Average time spent in the pit lane is about
#
# ### Who is the best constructor on pit stop performance (for 2021)?
# 1. Red Bull
# 2. Mercedes
# 3. Ferrari

# %% [markdown]
# <img style="width:100%" src="https://www.wsupercars.com/thumbnails-wide/Formula-1/Red-Bull-Racing/2022-Formula1-Red-Bull-Racing-RB18-001.jpg">
